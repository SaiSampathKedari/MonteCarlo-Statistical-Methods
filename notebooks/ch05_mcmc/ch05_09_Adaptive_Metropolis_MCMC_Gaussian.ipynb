# %%
import os
ROOT = os.path.dirname(os.path.dirname(os.getcwd()))
print(ROOT)
# Out:
# /home/saisampathkedari/MonteCarlo-Statistical-Methods

# %%
import numpy as np
import matplotlib.pyplot as plt
from functools import partial

# %%
from utils.montecarlo import *
from mcmc.algorithms.metropolis_hastings import *
from mcmc.utils.mcmc_utils import *
from mcmc.diagnostics.autocorrelation import *
from mcmc.utils.run_helpers import *
from mcmc.diagnostics.iac_and_ess import *
from mcmc.algorithms.adaptive_metropolis import *

# %% [markdown]
# # Adaptive Metropolis for 2D Gaussian Distribution

# %%
# Target Distribution 
target_mean = np.array([1,2])
target_cov = build_2D_covariance_matrix(1,1,0.5)
target_logpdf = lambda x: multivariate_normal_logpdf_eval(x.reshape(1,-1), mean=target_mean, cov=target_cov)[0]

# initial conditions
initial_sample = np.array([10,10])
initial_cov = build_2D_covariance_matrix(1,1,0.5) # from Laplace Approximation
num_samples = 50000

# Proposal Distribution properties
proposal_logpdf = proposal_mvn_logpdf_eval
proposal_sampler = proposal_mvn_sampler


## Metropolis-Hastings 
am_samples = am_mcmc(initial_sample, initial_cov, num_samples, target_logpdf, proposal_logpdf, proposal_sampler, freq_of_update=200, verbose=True)

samples = am_samples.samples
print("Accepted Samples Ratio:", am_samples.accept_rate)
# Out:
# Finished sample 1000, acceptance ratio = 0.262
# Finished sample 2000, acceptance ratio = 0.285
# Finished sample 3000, acceptance ratio = 0.306
# Finished sample 4000, acceptance ratio = 0.314
# Finished sample 5000, acceptance ratio = 0.324
# Finished sample 6000, acceptance ratio = 0.333
# Finished sample 7000, acceptance ratio = 0.337
# Finished sample 8000, acceptance ratio = 0.340
# Finished sample 9000, acceptance ratio = 0.339
# Finished sample 10000, acceptance ratio = 0.342
# Finished sample 11000, acceptance ratio = 0.342
# Finished sample 12000, acceptance ratio = 0.344
# Finished sample 13000, acceptance ratio = 0.345
# Finished sample 14000, acceptance ratio = 0.347
# Finished sample 15000, acceptance ratio = 0.349
# Finished sample 16000, acceptance ratio = 0.349
# Finished sample 17000, acceptance ratio = 0.349
# Finished sample 18000, acceptance ratio = 0.350
# Finished sample 19000, acceptance ratio = 0.351
# Finished sample 20000, acceptance ratio = 0.351
# Finished sample 21000, acceptance ratio = 0.351
# Finished sample 22000, acceptance ratio = 0.351
# Finished sample 23000, acceptance ratio = 0.351
# Finished sample 24000, acceptance ratio = 0.351
# Finished sample 25000, acceptance ratio = 0.351
# Finished sample 26000, acceptance ratio = 0.351
# Finished sample 27000, acceptance ratio = 0.350
# Finished sample 28000, acceptance ratio = 0.350
# Finished sample 29000, acceptance ratio = 0.352
# Finished sample 30000, acceptance ratio = 0.351
# Finished sample 31000, acceptance ratio = 0.351
# Finished sample 32000, acceptance ratio = 0.351
# Finished sample 33000, acceptance ratio = 0.351
# Finished sample 34000, acceptance ratio = 0.351
# Finished sample 35000, acceptance ratio = 0.351
# Finished sample 36000, acceptance ratio = 0.351
# Finished sample 37000, acceptance ratio = 0.352
# Finished sample 38000, acceptance ratio = 0.352
# Finished sample 39000, acceptance ratio = 0.353
# Finished sample 40000, acceptance ratio = 0.353
# Finished sample 41000, acceptance ratio = 0.352
# Finished sample 42000, acceptance ratio = 0.352
# Finished sample 43000, acceptance ratio = 0.352
# Finished sample 44000, acceptance ratio = 0.352
# Finished sample 45000, acceptance ratio = 0.353
# Finished sample 46000, acceptance ratio = 0.352
# Finished sample 47000, acceptance ratio = 0.352
# Finished sample 48000, acceptance ratio = 0.353
# Finished sample 49000, acceptance ratio = 0.352
# Accepted Samples Ratio: 0.3520070401408028

# %% [markdown]
# ## Burn-in

# %%
new_mh_result= mcmc_burnin_and_thin(am_samples, burnin_frac=0.5, thin_frac=1)
samples = new_mh_result.samples
print("Accepted Samples Ratio:", new_mh_result.accept_rate)
# Out:
# Accepted Samples Ratio: 0.35312

# %%
plt.close()
fig, axs, gs = scatter_matrix_clean(
    11,
    [samples],
    truths=target_mean,          # or None
    labels=[r"$\theta_1$", r"$\theta_2$"],
    hist_plot=False,
)
plt.show()

plt.close(12)
fig, axs, gs = scatter_matrix_clean(
    12,
    [samples],
    truths=target_mean,
    labels=[r"$\theta_1$", r"$\theta_2$"],
    hist_plot=True,
    nbins=70
)
plt.show()

# %% [markdown]
# ## Mixing

# %%
plot_mixing_2d(samples, dim_names=("x1", "x2"))

# %% [markdown]
# ## Autocorrelation

# %%
lags, acf = autocorrelation_vectorized(samples, max_lag=100)
plot_autocorrelation_2d(lags, acf, dim_names=("x1", "x2"))

# %% [markdown]
# ## Integrated Auto-Correlation & Effective Sample Size

# %%
iac, acf, lags = integrated_autocorrelation(samples, max_lag=300)
ess = effective_sample_size(samples, iac)

N = samples.shape[0]
efficiency = ess / N * 100  # percentage

print(f"Total samples: {N}\n")

for k in range(len(iac)):
    print(f"Dimension {k}:")
    print(f"  IAC:          {iac[k]:.4f}")
    print(f"  ESS:          {ess[k]:.2f}")
    print(f"  Efficiency:   {efficiency[k]:.1f}%   "
          f"({efficiency[k]:.1f}% as effective as independent samples)")
    print()
# Out:
# Total samples: 25000
#
# Dimension 0:
#   IAC:          8.8262
#   ESS:          2832.48
#   Efficiency:   11.3%   (11.3% as effective as independent samples)
#
# Dimension 1:
#   IAC:          7.1358
#   ESS:          3503.46
#   Efficiency:   14.0%   (14.0% as effective as independent samples)
