# %%
import os
ROOT = os.path.dirname(os.path.dirname(os.getcwd()))
print(ROOT)
# Out:
# /home/saisampathkedari/MonteCarlo-Statistical-Methods

# %%
import numpy as np
import matplotlib.pyplot as plt
from functools import partial

# %%
from mcmc.algorithms.adaptive_metropolis import *
from mcmc.distributions.banana import *
from mcmc.utils.mcmc_utils import *
from mcmc.diagnostics.autocorrelation import *
from mcmc.utils.run_helpers import *
from mcmc.diagnostics.iac_and_ess import *

# %% [markdown]
# ## Target Disribution : Banana Distribution

# %%
target_pdf_banana = pdf_banana_eval
target_logpdf_banana = logpdf_banana_eval

# %%
plt.figure(1, figsize=(10,8))

xgrid = np.linspace(-3,3,400)
ygrid = np.linspace(-8,2,400)

XX, YY, logpdf_evals = eval_on_2D_grid(xgrid, ygrid, target_pdf_banana)

plt.contourf(XX, YY, logpdf_evals)
plt.xlabel("x1")
plt.ylabel("x2")
plt.title("Banana Target Distribution")
save_path_1 = os.path.join(ROOT, "images/mcmc/Banana_target_distribution.png")
plt.tight_layout()
plt.savefig(save_path_1)
plt.show()

# %% [markdown]
# ## Target Distribution and Laplace Approximation

# %%
laplace_mean = np.array([0,-1])
laplace_cov = build_2D_covariance_matrix(1.0,1.0,0.9)

# %%
# -------------------------------------------------------
# 1. Define the grid
# -------------------------------------------------------
xgrid = np.linspace(-3, 3, 400)
ygrid = np.linspace(-8, 2, 300)

# -------------------------------------------------------
# 2. Evaluate Target distribution
# -------------------------------------------------------
XX, YY, target_vals = eval_on_2D_grid(
    xgrid,
    ygrid,
    target_pdf_banana)

# -------------------------------------------------------
# 3. Evaluate Laplace Approximation (Gaussian)
# -------------------------------------------------------
gauss_mean = laplace_mean
gauss_cov = laplace_cov

target_pdf_2d_Gaussian = lambda x: pdf_multivariate_normal_eval(x, gauss_mean, gauss_cov)

# Use scipy Gaussian evaluator on grid
XX, YY, laplace_target_vals = eval_on_2D_grid(
    xgrid,
    ygrid,
    target_pdf_2d_Gaussian)

# -------------------------------------------------------
# 4. Plot both distributions
# -------------------------------------------------------
plt.figure(figsize=(16, 8))

# Left subplot: Target Distribution
ax1 = plt.subplot(1, 2, 1)
ax1.contourf(XX, YY, target_vals)
ax1.set_title("Banana Target Distribution")
ax1.set_xlabel("x")
ax1.set_ylabel("y")
ax1.set_xlim(-3, 3)
ax1.set_ylim(-8, 2)

# Right subplot: Laplace approximation
ax2 = plt.subplot(1, 2, 2)
ax2.contourf(XX, YY, laplace_target_vals)
ax2.set_title("Laplace Approximation of Target")
ax2.set_xlabel("x")
ax2.set_ylabel("y")
ax2.set_xlim(-3, 3)
ax2.set_ylim(-8, 2)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Adaptive Metropolis for Banana Distribution

# %%
# initial conditions
initial_sample = laplace_mean
initial_cov = laplace_cov # from Laplace Approximation
num_samples = 50000

# Proposal Distribution properties
proposal_logpdf = proposal_mvn_logpdf_eval
proposal_sampler = proposal_mvn_sampler


## Adaptive-Metropolis 
am_result = am_mcmc(initial_sample, initial_cov, num_samples, target_logpdf_banana, proposal_logpdf, proposal_sampler, freq_of_update=200, verbose=True)

samples = am_result.samples
print("Accepted Samples Ratio:", am_result.accept_rate)
# Out:
# Finished sample 1000, acceptance ratio = 0.297
# Finished sample 2000, acceptance ratio = 0.216
# Finished sample 3000, acceptance ratio = 0.196
# Finished sample 4000, acceptance ratio = 0.182
# Finished sample 5000, acceptance ratio = 0.177
# Finished sample 6000, acceptance ratio = 0.173
# Finished sample 7000, acceptance ratio = 0.170
# Finished sample 8000, acceptance ratio = 0.165
# Finished sample 9000, acceptance ratio = 0.159
# Finished sample 10000, acceptance ratio = 0.156
# Finished sample 11000, acceptance ratio = 0.152
# Finished sample 12000, acceptance ratio = 0.148
# Finished sample 13000, acceptance ratio = 0.147
# Finished sample 14000, acceptance ratio = 0.146
# Finished sample 15000, acceptance ratio = 0.144
# Finished sample 16000, acceptance ratio = 0.143
# Finished sample 17000, acceptance ratio = 0.142
# Finished sample 18000, acceptance ratio = 0.140
# Finished sample 19000, acceptance ratio = 0.138
# Finished sample 20000, acceptance ratio = 0.137
# Finished sample 21000, acceptance ratio = 0.136
# Finished sample 22000, acceptance ratio = 0.135
# Finished sample 23000, acceptance ratio = 0.134
# Finished sample 24000, acceptance ratio = 0.133
# Finished sample 25000, acceptance ratio = 0.132
# Finished sample 26000, acceptance ratio = 0.132
# Finished sample 27000, acceptance ratio = 0.131
# Finished sample 28000, acceptance ratio = 0.130
# Finished sample 29000, acceptance ratio = 0.129
# Finished sample 30000, acceptance ratio = 0.128
# Finished sample 31000, acceptance ratio = 0.127
# Finished sample 32000, acceptance ratio = 0.126
# Finished sample 33000, acceptance ratio = 0.125
# Finished sample 34000, acceptance ratio = 0.125
# Finished sample 35000, acceptance ratio = 0.124
# Finished sample 36000, acceptance ratio = 0.123
# Finished sample 37000, acceptance ratio = 0.123
# Finished sample 38000, acceptance ratio = 0.122
# Finished sample 39000, acceptance ratio = 0.121
# Finished sample 40000, acceptance ratio = 0.121
# Finished sample 41000, acceptance ratio = 0.120
# Finished sample 42000, acceptance ratio = 0.120
# Finished sample 43000, acceptance ratio = 0.120
# Finished sample 44000, acceptance ratio = 0.120
# Finished sample 45000, acceptance ratio = 0.120
# Finished sample 46000, acceptance ratio = 0.119
# Finished sample 47000, acceptance ratio = 0.118
# Finished sample 48000, acceptance ratio = 0.118
# Finished sample 49000, acceptance ratio = 0.117
# Accepted Samples Ratio: 0.11710234204684093

# %% [markdown]
# ## Burn-In

# %%
new_am_result= mcmc_burnin_and_thin(am_result, burnin_frac=0.5, thin_frac=1)
samples = new_am_result.samples
print("Accepted Samples Ratio:", new_am_result.accept_rate)
# Out:
# Accepted Samples Ratio: 0.10192

# %%
plt.close()
fig, axs, gs = scatter_matrix_clean(
    11,
    [samples],
    truths=gauss_mean,          # or None
    labels=[r"$\theta_1$", r"$\theta_2$"],
    hist_plot=False,
)
plt.show()

plt.close(12)
fig, axs, gs = scatter_matrix_clean(
    12,
    [samples],
    truths=gauss_mean,
    labels=[r"$\theta_1$", r"$\theta_2$"],
    hist_plot=True,
    nbins=70
)
plt.show()

# %% [markdown]
# ## Estimation of Mean

# %%
print("True Mean        = ", np.array([0,-2]))
print("Estimated Mean   = ", np.mean(samples, axis=0))
# Out:
# True Mean        =  [ 0 -2]
# Estimated Mean   =  [-0.02503758 -2.12079804]

# %% [markdown]
# ## Mixing

# %%
plot_mixing_2d(samples, dim_names=("x1", "x2"))

# %% [markdown]
# ## Autocorrelation

# %%
lags, acf = autocorrelation_vectorized(samples, max_lag=100)
plot_autocorrelation_2d(lags, acf, dim_names=("x1", "x2"))

# %% [markdown]
# ## Integrated Auto-Correlation & Effective Sample Size

# %%
iac, acf, lags = integrated_autocorrelation(samples, max_lag=300)
ess = effective_sample_size(samples, iac)

N = samples.shape[0]
efficiency = ess / N * 100  # percentage

print(f"Total samples: {N}\n")

for k in range(len(iac)):
    print(f"Dimension {k}:")
    print(f"  IAC:          {iac[k]:.4f}")
    print(f"  ESS:          {ess[k]:.2f}")
    print(f"  Efficiency:   {efficiency[k]:.1f}%   "
          f"({efficiency[k]:.1f}% as effective as independent samples)")
    print()
# Out:
# Total samples: 25000
#
# Dimension 0:
#   IAC:          53.2406
#   ESS:          469.57
#   Efficiency:   1.9%   (1.9% as effective as independent samples)
#
# Dimension 1:
#   IAC:          115.7548
#   ESS:          215.97
#   Efficiency:   0.9%   (0.9% as effective as independent samples)
