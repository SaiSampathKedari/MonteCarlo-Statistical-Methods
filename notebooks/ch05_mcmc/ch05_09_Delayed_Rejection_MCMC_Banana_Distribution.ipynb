# %%
import os
ROOT = os.path.dirname(os.path.dirname(os.getcwd()))
print(ROOT)
# Out:
# /home/saisampathkedari/MonteCarlo-Statistical-Methods

# %%
import numpy as np
import matplotlib.pyplot as plt
from functools import partial

# %%
from utils.montecarlo import *
from mcmc.algorithms.metropolis_hastings import *
from mcmc.utils.mcmc_utils import *
from mcmc.diagnostics.autocorrelation import *
from mcmc.utils.run_helpers import *
from mcmc.diagnostics.iac_and_ess import *
from mcmc.algorithms.delayed_rejection import *
from mcmc.distributions.banana import *

# %% [markdown]
# # Delayed Rejection for Banana Distribution

# %%
target_pdf_banana = pdf_banana_eval
target_logpdf_banana = logpdf_banana_eval

# %%
laplace_mean = np.array([0,-1])
laplace_cov = build_2D_covariance_matrix(1.0,1.0,0.9)

# %%
# initial conditions
initial_sample = laplace_mean
initial_cov = laplace_cov # from Laplace Approximation
num_samples = 50000

# Proposal Distribution properties
proposal_logpdf = proposal_mvn_logpdf_eval
proposal_sampler = proposal_mvn_sampler


## Delayed Rejection
dr_result = dr_mcmc(initial_sample, initial_cov, num_samples, target_logpdf_banana, proposal_logpdf, proposal_sampler)

samples = dr_result.samples
print("Accepted Samples Ratio:", dr_result.accept_rate)
# Out:
# Finished sample 1000, acceptance ratio = 0.523
# Finished sample 2000, acceptance ratio = 0.534
# Finished sample 3000, acceptance ratio = 0.5486666666666666
# Finished sample 4000, acceptance ratio = 0.54825
# Finished sample 5000, acceptance ratio = 0.5544
# Finished sample 6000, acceptance ratio = 0.5555
# Finished sample 7000, acceptance ratio = 0.5494285714285714
# Finished sample 8000, acceptance ratio = 0.548375
# Finished sample 9000, acceptance ratio = 0.5501111111111111
# Finished sample 10000, acceptance ratio = 0.5499
# Finished sample 11000, acceptance ratio = 0.5537272727272727
# Finished sample 12000, acceptance ratio = 0.55325
# Finished sample 13000, acceptance ratio = 0.5516153846153846
# Finished sample 14000, acceptance ratio = 0.5421428571428571
# Finished sample 15000, acceptance ratio = 0.5414666666666667
# Finished sample 16000, acceptance ratio = 0.5406875
# Finished sample 17000, acceptance ratio = 0.5405294117647059
# Finished sample 18000, acceptance ratio = 0.5413888888888889
# Finished sample 19000, acceptance ratio = 0.5428947368421052
# Finished sample 20000, acceptance ratio = 0.5424
# Finished sample 21000, acceptance ratio = 0.5446666666666666
# Finished sample 22000, acceptance ratio = 0.546409090909091
# Finished sample 23000, acceptance ratio = 0.5477391304347826
# Finished sample 24000, acceptance ratio = 0.5490833333333334
# Finished sample 25000, acceptance ratio = 0.54804
# Finished sample 26000, acceptance ratio = 0.5483846153846154
# Finished sample 27000, acceptance ratio = 0.5484814814814815
# Finished sample 28000, acceptance ratio = 0.5493928571428571
# Finished sample 29000, acceptance ratio = 0.5498275862068965
# Finished sample 30000, acceptance ratio = 0.5508333333333333
# Finished sample 31000, acceptance ratio = 0.5498064516129032
# Finished sample 32000, acceptance ratio = 0.55
# Finished sample 33000, acceptance ratio = 0.5437575757575758
# Finished sample 34000, acceptance ratio = 0.5343235294117648
# Finished sample 35000, acceptance ratio = 0.5344
# Finished sample 36000, acceptance ratio = 0.5346666666666666
# Finished sample 37000, acceptance ratio = 0.5355405405405406
# Finished sample 38000, acceptance ratio = 0.5361578947368421
# Finished sample 39000, acceptance ratio = 0.5369487179487179
# Finished sample 40000, acceptance ratio = 0.53505
# Finished sample 41000, acceptance ratio = 0.5358536585365854
# Finished sample 42000, acceptance ratio = 0.5365714285714286
# Finished sample 43000, acceptance ratio = 0.5355348837209303
# Finished sample 44000, acceptance ratio = 0.5302954545454546
# Finished sample 45000, acceptance ratio = 0.5311555555555556
# Finished sample 46000, acceptance ratio = 0.5280652173913043
# Finished sample 47000, acceptance ratio = 0.5288723404255319
# Finished sample 48000, acceptance ratio = 0.5283541666666667
# Finished sample 49000, acceptance ratio = 0.529530612244898
# Accepted Samples Ratio: 0.5300506010120203

# %% [markdown]
# ## Burn-In

# %%
new_am_result= mcmc_burnin_and_thin(dr_result, burnin_frac=0.5, thin_frac=1)
samples = new_am_result.samples
print("Accepted Samples Ratio:", new_am_result.accept_rate)
# Out:
# Accepted Samples Ratio: 0.51204

# %%
ture_mean = np.array([0,-2])

# %%
plt.close()
fig, axs, gs = scatter_matrix_clean(
    11,
    [samples],
    truths=ture_mean,          # or None
    labels=[r"$\theta_1$", r"$\theta_2$"],
    hist_plot=False,
)
plt.show()

plt.close(12)
fig, axs, gs = scatter_matrix_clean(
    12,
    [samples],
    truths=ture_mean,
    labels=[r"$\theta_1$", r"$\theta_2$"],
    hist_plot=True,
    nbins=70
)
plt.show()

# %% [markdown]
# ## Estimation of Mean

# %%
print("True Mean        = ", np.array([0,-2]))
print("Estimated Mean   = ", np.mean(samples, axis=0))
# Out:
# True Mean        =  [ 0 -2]
# Estimated Mean   =  [-0.13769837 -2.98124379]

# %% [markdown]
# ## Mixing

# %%
plot_mixing_2d(samples, dim_names=("x1", "x2"))

# %% [markdown]
# ## Autocorrelation

# %%
lags, acf = autocorrelation_vectorized(samples, max_lag=100)
plot_autocorrelation_2d(lags, acf, dim_names=("x1", "x2"))

# %% [markdown]
# ## Integrated Auto-Correlation & Effective Sample Size

# %%
iac, acf, lags = integrated_autocorrelation(samples, max_lag=300)
ess = effective_sample_size(samples, iac)

N = samples.shape[0]
efficiency = ess / N * 100  # percentage

print(f"Total samples: {N}\n")

for k in range(len(iac)):
    print(f"Dimension {k}:")
    print(f"  IAC:          {iac[k]:.4f}")
    print(f"  ESS:          {ess[k]:.2f}")
    print(f"  Efficiency:   {efficiency[k]:.1f}%   "
          f"({efficiency[k]:.1f}% as effective as independent samples)")
    print()
# Out:
# Total samples: 25000
#
# Dimension 0:
#   IAC:          234.0649
#   ESS:          106.81
#   Efficiency:   0.4%   (0.4% as effective as independent samples)
#
# Dimension 1:
#   IAC:          407.0693
#   ESS:          61.41
#   Efficiency:   0.2%   (0.2% as effective as independent samples)
