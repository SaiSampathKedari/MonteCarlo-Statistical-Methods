# %%
from mc_core.sampling.gamma.gamma import *
from mc_core.utils.montecarlo import *
from matplotlib import pyplot as plt
import matplotlib
import numpy as np

# %% [markdown]
# ## Gamma Distribution

# %% [markdown]
# ## Direct Sampling

# %%
num_samples = 10000
alpha = 3
beta = 2
gamma_samples = gamma_int_parameters_sampleGenerator(alpha,beta, num_samples)

# %%
n = len(gamma_samples)
plt.hist(gamma_samples, bins=500, density=True, edgecolor="blue", alpha=0.7)
plt.xlim(0,20)
plt.title("Input Samples", fontsize=14)
plt.xlabel(r'$x$')
plt.ylabel("Probability Density")
plt.show()

# %% [markdown]
# ## Empirical vs Theoretical Distribution
