# %%
from exponential import *
from mc_core.utils.montecarlo import *
from matplotlib import pyplot as plt
import matplotlib

# %%
num_samples = 10000
lambda_ = 2
exponential_samples = exponential_sampleGenerator(lambda_, num_samples)

# %%
plt.hist(exponential_samples, bins=400, edgecolor="blue")
plt.xlim(0,16)
plt.title("Input Samples", fontsize=14)
plt.xlabel(r'$x$')
plt.ylabel("frequency")
plt.show()
